# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Collecting python-frontmatter
#   Downloading python_frontmatter-1.1.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: getorg in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (0.3.1)
# Requirement already satisfied: PyYAML in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from python-frontmatter) (6.0.3)
# Requirement already satisfied: geopy in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from getorg) (2.8.1)
# Requirement already satisfied: retrying in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from getorg) (1.4.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pynacl>=1.4.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pygithub->getorg) (1.6.2)
# Requirement already satisfied: requests>=2.14.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pygithub->getorg) (2.32.5)
# Requirement already satisfied: pyjwt>=2.4.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.11.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pygithub->getorg) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pygithub->getorg) (2.6.3)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (46.0.4)
# Requirement already satisfied: cffi>=2.0.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.0.0)
# Requirement already satisfied: pycparser in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from requests>=2.14.0->pygithub->getorg) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from requests>=2.14.0->pygithub->getorg) (2026.1.4)
# Downloading python_frontmatter-1.1.0-py3-none-any.whl (9.8 kB)
# Installing collected packages: python-frontmatter
# Successfully installed python-frontmatter-1.1.0
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")

# %%
# Set the default timeout, in seconds
TIMEOUT = 5

# Prepare to geolocate
geocoder = Nominatim(user_agent="academicpages.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %% [markdown]
# In the event that this times out with an error, double check to make sure that the location is can be properly geolocated.

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()
    description = f"{title}<br />{venue}; {location}"

    # Geocode the location and report the status
    try:
        location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        print(description, location_dict[description])
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")
# Out:
# Unstructured gridding and consistent discretizations for reservoirs with faults and complex wells<br />SPE Reservoir Simulation Conference (SPE RSC 2017); Montgomery, Texas, USA Montgomery County, Texas, United States
# A Comparison of Consistent Discretizations for Elliptic Problems on Polyhedral Grids<br />Finite Volumes for Complex Applications IX – Methods, Theoretical Aspects, Examples (FVCA IX); Online Online, Croix d'Argent, Montpellier, Hérault, Occitanie, France métropolitaine, France
# Ensemble Simulations With MRST With Examples from CO2 Foam Simulation<br />NCCS Webinar Series; Online Online, Croix d'Argent, Montpellier, Hérault, Occitanie, France métropolitaine, France
# Nonlinear Domain Decomposition Preconditioning for Field-Scale Subsurface Flow Simulation<br />SIAM Conference on Mathematical & Computational Issues in the Geosciences (GS21); Online Online, Croix d'Argent, Montpellier, Hérault, Occitanie, France métropolitaine, France
# How to use recent developments of the MATLAB Reservoir Simulation Toolbox for fast prototyping of complex fluid models<br />NCCS Webinar Series; Online Online, Croix d'Argent, Montpellier, Hérault, Occitanie, France métropolitaine, France
# Efficient Nonlinear Solution Strategies for Geothermal Energy Simulation<br />SIAM Conference on Mathematical & Computational Issues in the Geosciences (GS23); Bergen, Norway Bergen, Vestland, Norge
# Derisking geothermal energy by digitalization: a framework for modelling and optimization of underground thermal energy storage systems<br />GeoEnergy 2023; Bergen, Norway Bergen, Vestland, Norge
# Prediktive digitale tvillinger for optimal drift av GeoTermos<br />GeoTermos-festivalen 2025; Trondheim, Norway Trondheim, Trøndelag, Norge
# Dynamic Coarsening for Geothermal Applications<br />8th European Congress on Computational Methods in Applied Sciences and Engineering (ECCOMAS 2022); Oslo, Norway Oslo, Norge
# Comparison of implicit discontinuous Galerkin and Weno schemes on stratigraphic and unstructured grids<br />SIAM Conference on Mathematical & Computational Issues in the Geosciences (GS19); Houston, Texas, USA Houston, Harris County, Texas, United States
# Lavtemperatur geotermisk energi – Undergrunnen som varmekilde og varmelager<br />Seniorteknologenes høstkonferanse: Energi (Tekna); Oslo, Norway Oslo, Norge
# Additive Schwarz Preconditioned Exact Newton Method as a Nonlinear Preconditioner for Multiphase Porous Media Flow<br />17th European Conference on the Mathematics of Oil Recovery (ECMOR XVII); Online Online, Croix d'Argent, Montpellier, Hérault, Occitanie, France métropolitaine, France
# Use of dynamically adapted basis functions to accelerate multiscale simulation of complex geomodels<br />16th European Conference on the Mathematics of Oil Recovery (ECMOR XVI); Barcelona, Spain Barcelona, Barcelonès, Barcelona, Catalunya, España
# A feature-enriched multiscale solver for complex geomodels<br />SIAM Conference on Mathematical & Computational Issues in the Geosciences (GS17); Erlangen, Germany Erlangen, Bayern, Deutschland
# Reduced-Physics Multilevel Monte Carlo Methods for Uncertainty Quantification in Complex Reservoirs<br />12th InterPore Annual Meeting (InterPore 2020); Online Online, Croix d'Argent, Montpellier, Hérault, Occitanie, France métropolitaine, France
# Multilevel Monte Carlo Methods for Uncertainty Quantification in Reservoir Simulation<br />PhD Defense Trial Lecture; Trondheim, Norway Trondheim, Trøndelag, Norge
# Fimbul.jl – fast, flexible, robust, and differentiable geothermal energy simulation in Julia<br />Sixth EAGE Global Energy Transition Conference & Exhibition (GET 2025); Rotterdam, The Netherlands Rotterdam, Zuid-Holland, Nederland
# Dynamic coarsening for efficient simulation of geothermal energy applications<br />13th InterPore Annual Meeting (InterPore 2021); Online Online, Croix d'Argent, Montpellier, Hérault, Occitanie, France métropolitaine, France
# Towards digital twins for managing underground thermal energy storage<br />III International Conference on Computational Science and AI in Industry (CSAI 2023); Trondheim, Norway Trondheim, Trøndelag, Norge
# Proxy models for rapid simulation of underground thermal energy storage<br />Fifth EAGE Global Energy Transition Conference & Exhibition (GET 2024); Rotterdam, The Netherlands Rotterdam, Zuid-Holland, Nederland
# Tutorial: Reservoir modelling and simulation with MRST<br />Transform 2021; Online Online, Croix d'Argent, Montpellier, Hérault, Occitanie, France métropolitaine, France
# Implicit high-resolution compositional simulation with optimal ordering of unknowns and adaptive spatial refinement<br />SPE Reservoir Simulation Conference (SPE RSC 2019); Galveston, Texas, USA Galveston County, Texas, United States
# Predictive digital twins for underground thermal energy storage using differentiable programming<br />3rd IACM Digital Twins in Engineering Conference (DTE 2025) & 1st ECCOMAS Artificial Intelligence and Computational Methods in Applied Science (AICOMAS 2025); Paris, France Paris, Île-de-France, France métropolitaine, France
# Efficient Solvers for Field-Scale Simulation of Flow and Transport in Porous Media<br />PhD Defense; Trondheim, Norway Trondheim, Trøndelag, Norge
# Modeling and Optimization of Shallow Geothermal Heat Storage<br />European Conference on the Mathematics of Geological Reservoirs (ECMOR 2022); The Hague, The Netherlands Den Haag, Zuid-Holland, Nederland
# Geothermal Simulation Using MRST<br />12th InterPore Annual Meeting (InterPore 2020); Online Online, Croix d'Argent, Montpellier, Hérault, Occitanie, France métropolitaine, France
# High-resolution compositional reservoir simulation with dynamic coarsening and local timestepping for unstructured grids<br />SPE Reservoir Simulation Conference (SPE RSC 2021); Online Online, Croix d'Argent, Montpellier, Hérault, Occitanie, France métropolitaine, France

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
